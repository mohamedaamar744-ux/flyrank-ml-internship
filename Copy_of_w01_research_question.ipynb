# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamedaamar744-ux/flyrank-ml-internship/blob/main/Copy_of_w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mohamedaamar744-ux/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# **Lane: Refresh / Content Opportunity Scoring**
#
# I chose this lane because I want to identify which content pages should be reviewed first based on their performance signals. The goal is to help prioritize pages for review when resources are limited, rather than claiming that a refresh will definitely improve performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# **Decision:** Which content pages should be reviewed first for a possible refresh?
#
# **Action:** The content or SEO team can use the ranked list to prioritize pages for review and decide whether each page needs refreshing, expanding, protecting, pruning, or monitoring.
#
# **Cost of a wrong call:** A wrong recommendation could waste the team's time and resources on a page that does not need attention, while a page that actually needs review may be missed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The starter dataset contains **30,000 rows and 44 columns**. The `trend_direction` field shows that **16,262 rows are marked as `down`**, compared with **5,962 stable** and **4,388 up**. This suggests that there is a substantial set of content with declining performance that may be worth prioritizing for review.
#
# These numbers support the lane as a useful starting point, but a `down` trend does not mean that a refresh will definitely improve performance.

# %%
# !git clone https://github.com/mohamedaamar744-ux/flyrank-ml-internship.git
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 123 (delta 36), reused 101 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 1.86 MiB | 12.98 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
df=pd.read_csv("flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")
print(df.shape)
df.columns.tolist()
print(df["trend_direction"].value_counts())
# Out:
# (30000, 44)
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This work can identify observed patterns and directional signals in content performance. It can support decisions about which pages should be reviewed first based on measurable data.
#
# It cannot prove that a specific change caused a performance improvement, guarantee that a refresh will recover a page, or predict Google's ranking algorithm.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
